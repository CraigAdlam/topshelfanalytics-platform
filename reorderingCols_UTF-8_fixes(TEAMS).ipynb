# %% [markdown]
# ### Team Summary

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_summary.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_summary.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsAgainstPerGame', 'goalsFor', 'goalsForPerGame', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'penaltyKillNetPct', 'penaltyKillPct', 'pointPct', 'points', 'powerPlayNetPct', 'powerPlayPct', 'regulationAndOtWins', 'shotsAgainstPerGame', 'shotsForPerGame', 'teamFullName', 'teamId', 'wins', 'winsInRegulation', 'winsInShootout', 'teamShutouts']

# %%
df.columns
# Out:
# Index(['faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst',
#        'goalsAgainstPerGame', 'goalsFor', 'goalsForPerGame', 'homeRoad',
#        'losses', 'opponentTeamAbbrev', 'otLosses', 'penaltyKillNetPct',
#        'penaltyKillPct', 'pointPct', 'points', 'powerPlayNetPct',
#        'powerPlayPct', 'regulationAndOtWins', 'shotsAgainstPerGame',
#        'shotsForPerGame', 'teamFullName', 'teamId', 'wins', 'winsInRegulation',
#        'winsInShootout', 'teamShutouts'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", # not sure if there are ties, but website has them as a blank column probably due to past seasons when you could tie (OT tiebreaker since 2010-11)
    "otLosses", "points", "pointPct", "winsInRegulation",
    "regulationAndOtWins", "winsInShootout", "goalsFor",
    "goalsAgainst", "goalsForPerGame", "goalsAgainstPerGame",
    "teamShutouts", "powerPlayPct", "penaltyKillPct",
    "powerPlayNetPct", "penaltyKillNetPct", "shotsForPerGame",
    "shotsAgainstPerGame", "faceoffWinPct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointPct', 'winsInRegulation', 'regulationAndOtWins',
#        'winsInShootout', 'goalsFor', 'goalsAgainst', 'goalsForPerGame',
#        'goalsAgainstPerGame', 'teamShutouts', 'powerPlayPct', 'penaltyKillPct',
#        'powerPlayNetPct', 'penaltyKillNetPct', 'shotsForPerGame',
#        'shotsAgainstPerGame', 'faceoffWinPct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Days Between Games

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_daysbetweengames.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_daysbetweengames.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['daysRest', 'faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed', 'goalsAgainstPerGame', 'goalsForPerGame', 'homeRoad', 'losses', 'netGoalsPerGame', 'opponentTeamAbbrev', 'otLosses', 'penaltyKillPct', 'pointPct', 'points', 'powerPlayPct', 'ppOpportunitiesPerGame', 'shotDifferentialPerGame', 'shotsAgainstPerGame', 'shotsForPerGame', 'teamFullName', 'teamId', 'timesShorthandedPerGame', 'wins']

# %%
df.columns
# Out:
# Index(['daysRest', 'faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed',
#        'goalsAgainstPerGame', 'goalsForPerGame', 'homeRoad', 'losses',
#        'netGoalsPerGame', 'opponentTeamAbbrev', 'otLosses', 'penaltyKillPct',
#        'pointPct', 'points', 'powerPlayPct', 'ppOpportunitiesPerGame',
#        'shotDifferentialPerGame', 'shotsAgainstPerGame', 'shotsForPerGame',
#        'teamFullName', 'teamId', 'timesShorthandedPerGame', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "daysRest", "gamesPlayed", "wins",
    "losses", "otLosses", "points", "pointPct", "goalsForPerGame", 
    "goalsAgainstPerGame", "netGoalsPerGame", "shotsForPerGame",
    "shotsAgainstPerGame", "shotDifferentialPerGame",
    "ppOpportunitiesPerGame", "timesShorthandedPerGame",
    "powerPlayPct", "penaltyKillPct", "faceoffWinPct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'daysRest', 'gamesPlayed', 'wins', 'losses',
#        'otLosses', 'points', 'pointPct', 'goalsForPerGame',
#        'goalsAgainstPerGame', 'netGoalsPerGame', 'shotsForPerGame',
#        'shotsAgainstPerGame', 'shotDifferentialPerGame',
#        'ppOpportunitiesPerGame', 'timesShorthandedPerGame', 'powerPlayPct',
#        'penaltyKillPct', 'faceoffWinPct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Faceoff Percentages

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_faceoffpercentages.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_faceoffpercentages.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['defensiveZoneFaceoffPct', 'defensiveZoneFaceoffs', 'evFaceoffPct', 'evFaceoffs', 'faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'neutralZoneFaceoffPct', 'neutralZoneFaceoffs', 'offensiveZoneFaceoffPct', 'offensiveZoneFaceoffs', 'opponentTeamAbbrev', 'ppFaceoffPct', 'ppFaceoffs', 'shFaceoffPct', 'shFaceoffs', 'teamFullName', 'teamId', 'totalFaceoffs']

# %%
df.columns
# Out:
# Index(['defensiveZoneFaceoffPct', 'defensiveZoneFaceoffs', 'evFaceoffPct',
#        'evFaceoffs', 'faceoffWinPct', 'gameDate', 'gameId', 'gamesPlayed',
#        'homeRoad', 'neutralZoneFaceoffPct', 'neutralZoneFaceoffs',
#        'offensiveZoneFaceoffPct', 'offensiveZoneFaceoffs',
#        'opponentTeamAbbrev', 'ppFaceoffPct', 'ppFaceoffs', 'shFaceoffPct',
#        'shFaceoffs', 'teamFullName', 'teamId', 'totalFaceoffs'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "totalFaceoffs",
    "evFaceoffs", "ppFaceoffs", "shFaceoffs",
    "offensiveZoneFaceoffs", "neutralZoneFaceoffs", 
    "defensiveZoneFaceoffs", "faceoffWinPct", "evFaceoffPct",
    "ppFaceoffPct", "shFaceoffPct", "offensiveZoneFaceoffPct",
    "neutralZoneFaceoffPct", "defensiveZoneFaceoffPct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'totalFaceoffs', 'evFaceoffs',
#        'ppFaceoffs', 'shFaceoffs', 'offensiveZoneFaceoffs',
#        'neutralZoneFaceoffs', 'defensiveZoneFaceoffs', 'faceoffWinPct',
#        'evFaceoffPct', 'ppFaceoffPct', 'shFaceoffPct',
#        'offensiveZoneFaceoffPct', 'neutralZoneFaceoffPct',
#        'defensiveZoneFaceoffPct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ## Team Faceoff Wins

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_faceoffwins.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_faceoffwins.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['defensiveZoneFaceoffLosses', 'defensiveZoneFaceoffWins', 'defensiveZoneFaceoffs', 'evFaceoffs', 'evFaceoffsLost', 'evFaceoffsWon', 'faceoffWinPct', 'faceoffsLost', 'faceoffsWon', 'gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'neutralZoneFaceoffLosses', 'neutralZoneFaceoffWins', 'neutralZoneFaceoffs', 'offensiveZoneFaceoffLosses', 'offensiveZoneFaceoffWins', 'offensiveZoneFaceoffs', 'opponentTeamAbbrev', 'ppFaceoffs', 'ppFaceoffsLost', 'ppFaceoffsWon', 'shFaceoffs', 'shFaceoffsLost', 'shFaceoffsWon', 'teamFullName', 'teamId', 'totalFaceoffs']

# %%
df.columns
# Out:
# Index(['defensiveZoneFaceoffLosses', 'defensiveZoneFaceoffWins',
#        'defensiveZoneFaceoffs', 'evFaceoffs', 'evFaceoffsLost',
#        'evFaceoffsWon', 'faceoffWinPct', 'faceoffsLost', 'faceoffsWon',
#        'gameDate', 'gameId', 'gamesPlayed', 'homeRoad',
#        'neutralZoneFaceoffLosses', 'neutralZoneFaceoffWins',
#        'neutralZoneFaceoffs', 'offensiveZoneFaceoffLosses',
#        'offensiveZoneFaceoffWins', 'offensiveZoneFaceoffs',
#        'opponentTeamAbbrev', 'ppFaceoffs', 'ppFaceoffsLost', 'ppFaceoffsWon',
#        'shFaceoffs', 'shFaceoffsLost', 'shFaceoffsWon', 'teamFullName',
#        'teamId', 'totalFaceoffs'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "totalFaceoffs",
    "faceoffsWon", "faceoffsLost", "faceoffWinPct",
    "evFaceoffs", "evFaceoffsWon", "evFaceoffsLost",
    "ppFaceoffs", "ppFaceoffsWon", "ppFaceoffsLost",
    "shFaceoffs", "shFaceoffsWon", "shFaceoffsLost",
    "offensiveZoneFaceoffs", "offensiveZoneFaceoffWins",
    "offensiveZoneFaceoffLosses", "neutralZoneFaceoffs",
    "neutralZoneFaceoffWins", "neutralZoneFaceoffLosses",
    "defensiveZoneFaceoffs", "defensiveZoneFaceoffWins",
    "defensiveZoneFaceoffLosses"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'totalFaceoffs', 'faceoffsWon',
#        'faceoffsLost', 'faceoffWinPct', 'evFaceoffs', 'evFaceoffsWon',
#        'evFaceoffsLost', 'ppFaceoffs', 'ppFaceoffsWon', 'ppFaceoffsLost',
#        'shFaceoffs', 'shFaceoffsWon', 'shFaceoffsLost',
#        'offensiveZoneFaceoffs', 'offensiveZoneFaceoffWins',
#        'offensiveZoneFaceoffLosses', 'neutralZoneFaceoffs',
#        'neutralZoneFaceoffWins', 'neutralZoneFaceoffLosses',
#        'defensiveZoneFaceoffs', 'defensiveZoneFaceoffWins',
#        'defensiveZoneFaceoffLosses'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Goal Games

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_goalgames.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_goalgames.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'lossesOneGoalGames', 'lossesThreeGoalGames', 'lossesTwoGoalGames', 'opponentTeamAbbrev', 'otLosses', 'otLossesOneGoalGames', 'pointPct', 'points', 'teamFullName', 'teamId', 'ties', 'winPctOneGoalGames', 'winPctThreeGoalGames', 'winPctTwoGoalGames', 'wins', 'winsOneGoalGames', 'winsThreeGoalGames', 'winsTwoGoalGames']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'lossesOneGoalGames', 'lossesThreeGoalGames', 'lossesTwoGoalGames',
#        'opponentTeamAbbrev', 'otLosses', 'otLossesOneGoalGames', 'pointPct',
#        'points', 'teamFullName', 'teamId', 'ties', 'winPctOneGoalGames',
#        'winPctThreeGoalGames', 'winPctTwoGoalGames', 'wins',
#        'winsOneGoalGames', 'winsThreeGoalGames', 'winsTwoGoalGames'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", "ties",
    "otLosses", "points", "pointPct", "winPctOneGoalGames",
    "winPctTwoGoalGames", "winPctThreeGoalGames",
    "winsOneGoalGames", "winsTwoGoalGames", "winsThreeGoalGames",
    "lossesOneGoalGames", "lossesTwoGoalGames",
    "lossesThreeGoalGames", "otLossesOneGoalGames"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'ties',
#        'otLosses', 'points', 'pointPct', 'winPctOneGoalGames',
#        'winPctTwoGoalGames', 'winPctThreeGoalGames', 'winsOneGoalGames',
#        'winsTwoGoalGames', 'winsThreeGoalGames', 'lossesOneGoalGames',
#        'lossesTwoGoalGames', 'lossesThreeGoalGames', 'otLossesOneGoalGames'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Goals Against by Strength

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_goalsagainstbystrength.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_goalsagainstbystrength.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsAgainst3On3', 'goalsAgainst3On4', 'goalsAgainst3On5', 'goalsAgainst4On3', 'goalsAgainst4On4', 'goalsAgainst4On5', 'goalsAgainst5On3', 'goalsAgainst5On4', 'goalsAgainst5On5', 'goalsAgainstEmptyNet', 'goalsAgainstExtraAttacker', 'goalsAgainstPenaltyShots', 'goalsAgainstPerGame', 'goalsFor', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'teamFullName', 'teamId', 'ties', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsAgainst3On3',
#        'goalsAgainst3On4', 'goalsAgainst3On5', 'goalsAgainst4On3',
#        'goalsAgainst4On4', 'goalsAgainst4On5', 'goalsAgainst5On3',
#        'goalsAgainst5On4', 'goalsAgainst5On5', 'goalsAgainstEmptyNet',
#        'goalsAgainstExtraAttacker', 'goalsAgainstPenaltyShots',
#        'goalsAgainstPerGame', 'goalsFor', 'homeRoad', 'losses',
#        'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'teamFullName',
#        'teamId', 'ties', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", "ties",
    "otLosses", "points", "pointPct", "goalsFor", "goalsAgainst",
    "goalsAgainst5On5", "goalsAgainst4On4", "goalsAgainst3On3",
    "goalsAgainst5On4", "goalsAgainst5On3", "goalsAgainst4On3",
    "goalsAgainst3On4", "goalsAgainst3On5", "goalsAgainst4On5",
    "goalsAgainstPenaltyShots", "goalsAgainstEmptyNet",
    "goalsAgainstExtraAttacker", "goalsAgainstPerGame"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'ties',
#        'otLosses', 'points', 'pointPct', 'goalsFor', 'goalsAgainst',
#        'goalsAgainst5On5', 'goalsAgainst4On4', 'goalsAgainst3On3',
#        'goalsAgainst5On4', 'goalsAgainst5On3', 'goalsAgainst4On3',
#        'goalsAgainst3On4', 'goalsAgainst3On5', 'goalsAgainst4On5',
#        'goalsAgainstPenaltyShots', 'goalsAgainstEmptyNet',
#        'goalsAgainstExtraAttacker', 'goalsAgainstPerGame'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Skater Penalty Kill

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_goalsbyperiod.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_goalsbyperiod.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['evGoalsFor', 'gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsFor', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'period1GoalsAgainst', 'period1GoalsFor', 'period2GoalsAgainst', 'period2GoalsFor', 'period3GoalsAgainst', 'period3GoalsFor', 'periodOtGoalsAgainst', 'periodOtGoalsFor', 'pointPct', 'points', 'ppGoalsFor', 'shGoalsFor', 'teamFullName', 'teamId', 'wins']

# %%
df.columns
# Out:
# Index(['evGoalsFor', 'gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst',
#        'goalsFor', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses',
#        'period1GoalsAgainst', 'period1GoalsFor', 'period2GoalsAgainst',
#        'period2GoalsFor', 'period3GoalsAgainst', 'period3GoalsFor',
#        'periodOtGoalsAgainst', 'periodOtGoalsFor', 'pointPct', 'points',
#        'ppGoalsFor', 'shGoalsFor', 'teamFullName', 'teamId', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", "otLosses",
    "points", "pointPct", "evGoalsFor", "ppGoalsFor", "shGoalsFor",
    "goalsFor", "period1GoalsFor", "period2GoalsFor", "period3GoalsFor",
    "periodOtGoalsFor", "goalsAgainst", "period1GoalsAgainst",
    "period2GoalsAgainst", "period3GoalsAgainst", "periodOtGoalsAgainst"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointPct', 'evGoalsFor', 'ppGoalsFor', 'shGoalsFor',
#        'goalsFor', 'period1GoalsFor', 'period2GoalsFor', 'period3GoalsFor',
#        'periodOtGoalsFor', 'goalsAgainst', 'period1GoalsAgainst',
#        'period2GoalsAgainst', 'period3GoalsAgainst', 'periodOtGoalsAgainst'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Goals for By Strength

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_goalsforbystrength.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_goalsforbystrength.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsFor', 'goalsFor3On3', 'goalsFor3On4', 'goalsFor3On5', 'goalsFor4On3', 'goalsFor4On4', 'goalsFor4On5', 'goalsFor5On3', 'goalsFor5On4', 'goalsFor5On5', 'goalsForEmptyNet', 'goalsForExtraAttacker', 'goalsForPenaltyShots', 'goalsForPerGame', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'teamFullName', 'teamId', 'ties', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsFor',
#        'goalsFor3On3', 'goalsFor3On4', 'goalsFor3On5', 'goalsFor4On3',
#        'goalsFor4On4', 'goalsFor4On5', 'goalsFor5On3', 'goalsFor5On4',
#        'goalsFor5On5', 'goalsForEmptyNet', 'goalsForExtraAttacker',
#        'goalsForPenaltyShots', 'goalsForPerGame', 'homeRoad', 'losses',
#        'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'teamFullName',
#        'teamId', 'ties', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", "ties",
    "otLosses", "points", "pointPct", "goalsFor", "goalsAgainst",
    "goalsFor5On5", "goalsFor4On4", "goalsFor3On3", "goalsFor5On4",
    "goalsFor5On3", "goalsFor4On3", "goalsFor3On4", "goalsFor3On5",
    "goalsFor4On5", "goalsForPenaltyShots", "goalsForEmptyNet",
    "goalsForExtraAttacker", "goalsForPerGame"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'ties',
#        'otLosses', 'points', 'pointPct', 'goalsFor', 'goalsAgainst',
#        'goalsFor5On5', 'goalsFor4On4', 'goalsFor3On3', 'goalsFor5On4',
#        'goalsFor5On3', 'goalsFor4On3', 'goalsFor3On4', 'goalsFor3On5',
#        'goalsFor4On5', 'goalsForPenaltyShots', 'goalsForEmptyNet',
#        'goalsForExtraAttacker', 'goalsForPerGame'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Goals for by Strength Goalie Pull

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_goalsforbystrengthgoaliepull.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_goalsforbystrengthgoaliepull.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsFor3On4', 'goalsFor3On5', 'goalsFor3On6', 'goalsFor4On3', 'goalsFor4On4', 'goalsFor4On5', 'goalsFor4On6', 'goalsFor5On3', 'goalsFor5On4', 'goalsFor5On5', 'goalsFor5On6', 'goalsFor6On3', 'goalsFor6On4', 'goalsFor6On5', 'goalsFor6On6', 'goalsForAllPulls', 'goalsForPerGame', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'teamFullName', 'teamId', 'ties', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst', 'goalsFor3On4',
#        'goalsFor3On5', 'goalsFor3On6', 'goalsFor4On3', 'goalsFor4On4',
#        'goalsFor4On5', 'goalsFor4On6', 'goalsFor5On3', 'goalsFor5On4',
#        'goalsFor5On5', 'goalsFor5On6', 'goalsFor6On3', 'goalsFor6On4',
#        'goalsFor6On5', 'goalsFor6On6', 'goalsForAllPulls', 'goalsForPerGame',
#        'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct',
#        'points', 'teamFullName', 'teamId', 'ties', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses", "ties",
    "otLosses", "points", "pointPct", "goalsForAllPulls",
    "goalsAgainst", "goalsFor6On5", "goalsFor6On4", "goalsFor6On3",
    "goalsFor3On6", "goalsFor4On6", "goalsFor5On6", "goalsFor5On4",
    "goalsFor5On3", "goalsFor4On5", "goalsFor4On3", "goalsFor3On4",
    "goalsFor3On5", "goalsFor6On6", "goalsFor5On5", "goalsFor4On4",
    "goalsForPerGame"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'ties',
#        'otLosses', 'points', 'pointPct', 'goalsForAllPulls', 'goalsAgainst',
#        'goalsFor6On5', 'goalsFor6On4', 'goalsFor6On3', 'goalsFor3On6',
#        'goalsFor4On6', 'goalsFor5On6', 'goalsFor5On4', 'goalsFor5On3',
#        'goalsFor4On5', 'goalsFor4On3', 'goalsFor3On4', 'goalsFor3On5',
#        'goalsFor6On6', 'goalsFor5On5', 'goalsFor4On4', 'goalsForPerGame'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Leading Trailing

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_leadingtrailing.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_leadingtrailing.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'lossLeadPeriod1', 'lossLeadPeriod2', 'lossTrailPeriod1', 'lossTrailPeriod2', 'opponentTeamAbbrev', 'otLossLeadPeriod1', 'otLossLeadPeriod2', 'otLossTrailPeriod1', 'otLossTrailPeriod2', 'period1GoalsAgainst', 'period1GoalsFor', 'period2GoalsAgainst', 'period2GoalsFor', 'pointPct', 'teamFullName', 'teamId', 'tiesLeadPeriod1', 'tiesLeadPeriod2', 'tiesTrailPeriod1', 'tiesTrailPeriod2', 'winPctLeadPeriod1', 'winPctLeadPeriod2', 'winPctTrailPeriod1', 'winPctTrailPeriod2', 'winsLeadPeriod1', 'winsLeadPeriod2', 'winsTrailPeriod1', 'winsTrailPeriod2']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'lossLeadPeriod1',
#        'lossLeadPeriod2', 'lossTrailPeriod1', 'lossTrailPeriod2',
#        'opponentTeamAbbrev', 'otLossLeadPeriod1', 'otLossLeadPeriod2',
#        'otLossTrailPeriod1', 'otLossTrailPeriod2', 'period1GoalsAgainst',
#        'period1GoalsFor', 'period2GoalsAgainst', 'period2GoalsFor', 'pointPct',
#        'teamFullName', 'teamId', 'tiesLeadPeriod1', 'tiesLeadPeriod2',
#        'tiesTrailPeriod1', 'tiesTrailPeriod2', 'winPctLeadPeriod1',
#        'winPctLeadPeriod2', 'winPctTrailPeriod1', 'winPctTrailPeriod2',
#        'winsLeadPeriod1', 'winsLeadPeriod2', 'winsTrailPeriod1',
#        'winsTrailPeriod2'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "pointPct",
    "period1GoalsFor", "period1GoalsAgainst", "period2GoalsFor",
    "period2GoalsAgainst", "winsLeadPeriod1", "lossLeadPeriod1",
    "tiesLeadPeriod1", "otLossLeadPeriod1", "winPctLeadPeriod1",
    "winsLeadPeriod2", "lossLeadPeriod2", "tiesLeadPeriod2",
    "otLossLeadPeriod2", "winPctLeadPeriod2", "winsTrailPeriod1",
    "lossTrailPeriod1", "tiesTrailPeriod1", "otLossTrailPeriod1",
    "winPctTrailPeriod1", "winsTrailPeriod2", "lossTrailPeriod2",
    "tiesTrailPeriod2", "otLossTrailPeriod2", "winPctTrailPeriod2"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'pointPct', 'period1GoalsFor',
#        'period1GoalsAgainst', 'period2GoalsFor', 'period2GoalsAgainst',
#        'winsLeadPeriod1', 'lossLeadPeriod1', 'tiesLeadPeriod1',
#        'otLossLeadPeriod1', 'winPctLeadPeriod1', 'winsLeadPeriod2',
#        'lossLeadPeriod2', 'tiesLeadPeriod2', 'otLossLeadPeriod2',
#        'winPctLeadPeriod2', 'winsTrailPeriod1', 'lossTrailPeriod1',
#        'tiesTrailPeriod1', 'otLossTrailPeriod1', 'winPctTrailPeriod1',
#        'winsTrailPeriod2', 'lossTrailPeriod2', 'tiesTrailPeriod2',
#        'otLossTrailPeriod2', 'winPctTrailPeriod2'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Outshoot Outshot By

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_outshootoutshotby.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_outshootoutshotby.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'lossesEvenShots', 'lossesOutshootOpponent', 'lossesOutshotByOpponent', 'netShotsPerGame', 'opponentTeamAbbrev', 'otLosses', 'otLossesEvenShots', 'otLossesOutshootOpponent', 'otLossesOutshotByOpponent', 'pointPct', 'points', 'shotsAgainstPerGame', 'shotsForPerGame', 'teamFullName', 'teamId', 'tiesEvenShots', 'tiesOutshootOpponent', 'tiesOutshotByOpponent', 'wins', 'winsEvenShots', 'winsOutshootOpponent', 'winsOutshotByOpponent']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'lossesEvenShots', 'lossesOutshootOpponent', 'lossesOutshotByOpponent',
#        'netShotsPerGame', 'opponentTeamAbbrev', 'otLosses',
#        'otLossesEvenShots', 'otLossesOutshootOpponent',
#        'otLossesOutshotByOpponent', 'pointPct', 'points',
#        'shotsAgainstPerGame', 'shotsForPerGame', 'teamFullName', 'teamId',
#        'tiesEvenShots', 'tiesOutshootOpponent', 'tiesOutshotByOpponent',
#        'wins', 'winsEvenShots', 'winsOutshootOpponent',
#        'winsOutshotByOpponent'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "pointPct", "shotsForPerGame",
    "shotsAgainstPerGame", "netShotsPerGame", "winsOutshootOpponent",
    "lossesOutshootOpponent", "tiesOutshootOpponent",
    "otLossesOutshootOpponent", "winsOutshotByOpponent",
    "lossesOutshotByOpponent", "tiesOutshotByOpponent",
    "otLossesOutshotByOpponent", "winsEvenShots", "lossesEvenShots",
    "tiesEvenShots", "otLossesEvenShots"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointPct', 'shotsForPerGame', 'shotsAgainstPerGame',
#        'netShotsPerGame', 'winsOutshootOpponent', 'lossesOutshootOpponent',
#        'tiesOutshootOpponent', 'otLossesOutshootOpponent',
#        'winsOutshotByOpponent', 'lossesOutshotByOpponent',
#        'tiesOutshotByOpponent', 'otLossesOutshotByOpponent', 'winsEvenShots',
#        'lossesEvenShots', 'tiesEvenShots', 'otLossesEvenShots'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Penalties

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_penalties.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_penalties.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['benchMinorPenalties', 'gameDate', 'gameId', 'gameMisconducts', 'gamesPlayed', 'homeRoad', 'losses', 'majors', 'matchPenalties', 'minors', 'misconducts', 'netPenalties', 'netPenaltiesPer60', 'opponentTeamAbbrev', 'otLosses', 'penalties', 'penaltiesDrawnPer60', 'penaltiesTakenPer60', 'penaltyMinutes', 'penaltySecondsPerGame', 'points', 'teamFullName', 'teamId', 'totalPenaltiesDrawn', 'wins']

# %%
df.columns
# Out:
# Index(['benchMinorPenalties', 'gameDate', 'gameId', 'gameMisconducts',
#        'gamesPlayed', 'homeRoad', 'losses', 'majors', 'matchPenalties',
#        'minors', 'misconducts', 'netPenalties', 'netPenaltiesPer60',
#        'opponentTeamAbbrev', 'otLosses', 'penalties', 'penaltiesDrawnPer60',
#        'penaltiesTakenPer60', 'penaltyMinutes', 'penaltySecondsPerGame',
#        'points', 'teamFullName', 'teamId', 'totalPenaltiesDrawn', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "penaltyMinutes", "penaltySecondsPerGame",
    "totalPenaltiesDrawn", "penalties", "netPenalties",
    "penaltiesDrawnPer60", "penaltiesTakenPer60", "netPenaltiesPer60",
    "benchMinorPenalties", "minors", "majors", "matchPenalties",
    "misconducts", "gameMisconducts"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'penaltyMinutes', 'penaltySecondsPerGame',
#        'totalPenaltiesDrawn', 'penalties', 'netPenalties',
#        'penaltiesDrawnPer60', 'penaltiesTakenPer60', 'netPenaltiesPer60',
#        'benchMinorPenalties', 'minors', 'majors', 'matchPenalties',
#        'misconducts', 'gameMisconducts'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Penalty Kill

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_penaltykill.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_penaltykill.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'penaltyKillNetPct', 'penaltyKillPct', 'pkNetGoals', 'pkNetGoalsPerGame', 'pkTimeOnIcePerGame', 'points', 'pointsPct', 'ppGoalsAgainst', 'ppGoalsAgainstPerGame', 'shGoalsFor', 'shGoalsForPerGame', 'teamFullName', 'teamId', 'timesShorthanded', 'timesShorthandedPerGame', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'opponentTeamAbbrev', 'otLosses', 'penaltyKillNetPct', 'penaltyKillPct',
#        'pkNetGoals', 'pkNetGoalsPerGame', 'pkTimeOnIcePerGame', 'points',
#        'pointsPct', 'ppGoalsAgainst', 'ppGoalsAgainstPerGame', 'shGoalsFor',
#        'shGoalsForPerGame', 'teamFullName', 'teamId', 'timesShorthanded',
#        'timesShorthandedPerGame', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "pointsPct", "timesShorthanded",
    "ppGoalsAgainst", "shGoalsFor", "pkNetGoals",
    "pkTimeOnIcePerGame", "timesShorthandedPerGame",
    "ppGoalsAgainstPerGame", "shGoalsForPerGame",
    "pkNetGoalsPerGame", "penaltyKillPct", "penaltyKillNetPct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointsPct', 'timesShorthanded', 'ppGoalsAgainst',
#        'shGoalsFor', 'pkNetGoals', 'pkTimeOnIcePerGame',
#        'timesShorthandedPerGame', 'ppGoalsAgainstPerGame', 'shGoalsForPerGame',
#        'pkNetGoalsPerGame', 'penaltyKillPct', 'penaltyKillNetPct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Penalty Kill Time

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_penaltykilltime.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_penaltykilltime.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst3v4', 'goalsAgainst3v5', 'goalsAgainst4v5', 'homeRoad', 'opponentTeamAbbrev', 'overallPenaltyKillPct', 'penaltyKillPct3v4', 'penaltyKillPct3v5', 'penaltyKillPct4v5', 'pointPct', 'shorthandedGoalsAgainst', 'teamFullName', 'teamId', 'timeOnIce3v4', 'timeOnIce3v5', 'timeOnIce4v5', 'timeOnIceShorthanded', 'timesShorthanded', 'timesShorthanded3v4', 'timesShorthanded3v5', 'timesShorthanded4v5']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsAgainst3v4',
#        'goalsAgainst3v5', 'goalsAgainst4v5', 'homeRoad', 'opponentTeamAbbrev',
#        'overallPenaltyKillPct', 'penaltyKillPct3v4', 'penaltyKillPct3v5',
#        'penaltyKillPct4v5', 'pointPct', 'shorthandedGoalsAgainst',
#        'teamFullName', 'teamId', 'timeOnIce3v4', 'timeOnIce3v5',
#        'timeOnIce4v5', 'timeOnIceShorthanded', 'timesShorthanded',
#        'timesShorthanded3v4', 'timesShorthanded3v5', 'timesShorthanded4v5'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "pointPct",
    "timeOnIceShorthanded", "timesShorthanded",
    "shorthandedGoalsAgainst", "overallPenaltyKillPct",
    "timeOnIce4v5", "timesShorthanded4v5", "goalsAgainst4v5",
    "penaltyKillPct4v5", "timeOnIce3v5", "timesShorthanded3v5",
    "goalsAgainst3v5", "penaltyKillPct3v5", "timeOnIce3v4",
    "timesShorthanded3v4", "goalsAgainst3v4", "penaltyKillPct3v4"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'pointPct', 'timeOnIceShorthanded',
#        'timesShorthanded', 'shorthandedGoalsAgainst', 'overallPenaltyKillPct',
#        'timeOnIce4v5', 'timesShorthanded4v5', 'goalsAgainst4v5',
#        'penaltyKillPct4v5', 'timeOnIce3v5', 'timesShorthanded3v5',
#        'goalsAgainst3v5', 'penaltyKillPct3v5', 'timeOnIce3v4',
#        'timesShorthanded3v4', 'goalsAgainst3v4', 'penaltyKillPct3v4'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Percentages

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_percentages.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_percentages.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsForPct', 'homeRoad', 'opponentTeamAbbrev', 'pointPct', 'points', 'satPct', 'satPctAhead', 'satPctBehind', 'satPctClose', 'satPctTied', 'savePct5v5', 'shootingPct5v5', 'shootingPlusSavePct5v5', 'teamFullName', 'teamId', 'usatPct', 'usatPctAhead', 'usatPctBehind', 'usatPctClose', 'usatPctTied', 'zoneStartPct5v5']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsForPct', 'homeRoad',
#        'opponentTeamAbbrev', 'pointPct', 'points', 'satPct', 'satPctAhead',
#        'satPctBehind', 'satPctClose', 'satPctTied', 'savePct5v5',
#        'shootingPct5v5', 'shootingPlusSavePct5v5', 'teamFullName', 'teamId',
#        'usatPct', 'usatPctAhead', 'usatPctBehind', 'usatPctClose',
#        'usatPctTied', 'zoneStartPct5v5'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "points", "pointPct",
    "goalsForPct", "satPct", "satPctAhead", "satPctTied",
    "satPctBehind", "satPctClose", "usatPct", "usatPctAhead",
    "usatPctTied", "usatPctBehind", "usatPctClose",
    "zoneStartPct5v5", "shootingPct5v5", "savePct5v5",
    "shootingPlusSavePct5v5"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'points', 'pointPct',
#        'goalsForPct', 'satPct', 'satPctAhead', 'satPctTied', 'satPctBehind',
#        'satPctClose', 'usatPct', 'usatPctAhead', 'usatPctTied',
#        'usatPctBehind', 'usatPctClose', 'zoneStartPct5v5', 'shootingPct5v5',
#        'savePct5v5', 'shootingPlusSavePct5v5'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Power Play

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_powerplay.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_powerplay.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'powerPlayGoalsFor', 'powerPlayNetPct', 'powerPlayPct', 'ppGoalsPerGame', 'ppNetGoals', 'ppNetGoalsPerGame', 'ppOpportunities', 'ppOpportunitiesPerGame', 'ppTimeOnIcePerGame', 'shGoalsAgainst', 'shGoalsAgainstPerGame', 'teamFullName', 'teamId', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points',
#        'powerPlayGoalsFor', 'powerPlayNetPct', 'powerPlayPct',
#        'ppGoalsPerGame', 'ppNetGoals', 'ppNetGoalsPerGame', 'ppOpportunities',
#        'ppOpportunitiesPerGame', 'ppTimeOnIcePerGame', 'shGoalsAgainst',
#        'shGoalsAgainstPerGame', 'teamFullName', 'teamId', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "pointPct", "ppOpportunities",
    "powerPlayGoalsFor", "shGoalsAgainst", "ppNetGoals",
    "ppTimeOnIcePerGame", "ppOpportunitiesPerGame",
    "ppGoalsPerGame", "shGoalsAgainstPerGame",
    "ppNetGoalsPerGame", "powerPlayPct", "powerPlayNetPct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointPct', 'ppOpportunities', 'powerPlayGoalsFor',
#        'shGoalsAgainst', 'ppNetGoals', 'ppTimeOnIcePerGame',
#        'ppOpportunitiesPerGame', 'ppGoalsPerGame', 'shGoalsAgainstPerGame',
#        'ppNetGoalsPerGame', 'powerPlayPct', 'powerPlayNetPct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Power Play Time

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_powerplaytime.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_powerplaytime.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goals4v3', 'goals5v3', 'goals5v4', 'homeRoad', 'opponentTeamAbbrev', 'opportunities4v3', 'opportunities5v3', 'opportunities5v4', 'overallPowerPlayPct', 'pointPct', 'powerPlayGoalsFor', 'powerPlayPct4v3', 'powerPlayPct5v3', 'powerPlayPct5v4', 'ppOpportunities', 'teamFullName', 'teamId', 'timeOnIce4v3', 'timeOnIce5v3', 'timeOnIce5v4', 'timeOnIcePp']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goals4v3', 'goals5v3', 'goals5v4',
#        'homeRoad', 'opponentTeamAbbrev', 'opportunities4v3',
#        'opportunities5v3', 'opportunities5v4', 'overallPowerPlayPct',
#        'pointPct', 'powerPlayGoalsFor', 'powerPlayPct4v3', 'powerPlayPct5v3',
#        'powerPlayPct5v4', 'ppOpportunities', 'teamFullName', 'teamId',
#        'timeOnIce4v3', 'timeOnIce5v3', 'timeOnIce5v4', 'timeOnIcePp'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "pointPct",
    "timeOnIcePp", "ppOpportunities", "powerPlayGoalsFor",
    "overallPowerPlayPct", "timeOnIce5v4", "opportunities5v4",
    "goals5v4", "powerPlayPct5v4", "timeOnIce5v3",
    "opportunities5v3", "goals5v3", "powerPlayPct5v3",
    "timeOnIce4v3", "opportunities4v3", "goals4v3",
    "powerPlayPct4v3"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'pointPct', 'timeOnIcePp',
#        'ppOpportunities', 'powerPlayGoalsFor', 'overallPowerPlayPct',
#        'timeOnIce5v4', 'opportunities5v4', 'goals5v4', 'powerPlayPct5v4',
#        'timeOnIce5v3', 'opportunities5v3', 'goals5v3', 'powerPlayPct5v3',
#        'timeOnIce4v3', 'opportunities4v3', 'goals4v3', 'powerPlayPct4v3'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Realtime

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_realtime.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_realtime.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['blockedShots', 'blockedShotsPer60', 'emptyNetGoals', 'gameDate', 'gameId', 'gamesPlayed', 'giveaways', 'giveawaysPer60', 'hits', 'hitsPer60', 'homeRoad', 'missedShots', 'opponentTeamAbbrev', 'satPct', 'takeaways', 'takeawaysPer60', 'teamFullName', 'teamId', 'timeOnIcePerGame5v5', 'shotAttemptsBlocked', 'shots', 'totalShotAttempts']

# %%
df.columns
# Out:
# Index(['blockedShots', 'blockedShotsPer60', 'emptyNetGoals', 'gameDate',
#        'gameId', 'gamesPlayed', 'giveaways', 'giveawaysPer60', 'hits',
#        'hitsPer60', 'homeRoad', 'missedShots', 'opponentTeamAbbrev', 'satPct',
#        'takeaways', 'takeawaysPer60', 'teamFullName', 'teamId',
#        'timeOnIcePerGame5v5', 'shotAttemptsBlocked', 'shots',
#        'totalShotAttempts'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "timeOnIcePerGame5v5",
    "satPct", "hits", "hitsPer60", "blockedShots",
    "blockedShotsPer60", "giveaways", "giveawaysPer60",
    "takeaways", "takeawaysPer60", "emptyNetGoals", "shots",
    "missedShots", "shotAttemptsBlocked", "totalShotAttempts"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'timeOnIcePerGame5v5', 'satPct',
#        'hits', 'hitsPer60', 'blockedShots', 'blockedShotsPer60', 'giveaways',
#        'giveawaysPer60', 'takeaways', 'takeawaysPer60', 'emptyNetGoals',
#        'shots', 'missedShots', 'shotAttemptsBlocked', 'totalShotAttempts'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Score Trail First

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_scoretrailfirst.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_scoretrailfirst.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'lossesScoringFirst', 'lossesTrailingFirst', 'opponentTeamAbbrev', 'otLosses', 'otLossesScoringFirst', 'otLossesTrailingFirst', 'points', 'scoringFirstGamesPlayed', 'teamFullName', 'teamId', 'tiesScoringFirst', 'tiesTrailingFirst', 'trailingFirstGamesPlayed', 'winPctScoringFirst', 'winPctTrailingFirst', 'wins', 'winsScoringFirst', 'winsTrailingFirst']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'lossesScoringFirst', 'lossesTrailingFirst', 'opponentTeamAbbrev',
#        'otLosses', 'otLossesScoringFirst', 'otLossesTrailingFirst', 'points',
#        'scoringFirstGamesPlayed', 'teamFullName', 'teamId', 'tiesScoringFirst',
#        'tiesTrailingFirst', 'trailingFirstGamesPlayed', 'winPctScoringFirst',
#        'winPctTrailingFirst', 'wins', 'winsScoringFirst', 'winsTrailingFirst'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "scoringFirstGamesPlayed",
    "winsScoringFirst", "lossesScoringFirst", "tiesScoringFirst",
    "otLossesScoringFirst", "winPctScoringFirst",
    "trailingFirstGamesPlayed", "winsTrailingFirst",
    "lossesTrailingFirst", "tiesTrailingFirst",
    "otLossesTrailingFirst", "winPctTrailingFirst"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'scoringFirstGamesPlayed', 'winsScoringFirst',
#        'lossesScoringFirst', 'tiesScoringFirst', 'otLossesScoringFirst',
#        'winPctScoringFirst', 'trailingFirstGamesPlayed', 'winsTrailingFirst',
#        'lossesTrailingFirst', 'tiesTrailingFirst', 'otLossesTrailingFirst',
#        'winPctTrailingFirst'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Shootout

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_shootout.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_shootout.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses', 'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points', 'shootoutGamesPlayed', 'shootoutGoals', 'shootoutGoalsAgainst', 'shootoutLosses', 'shootoutPoints', 'shootoutSavePct', 'shootoutSaves', 'shootoutShootingPct', 'shootoutShootingPlusSavePct', 'shootoutShots', 'shootoutShotsAgainst', 'shootoutWinPct', 'shootoutWins', 'teamFullName', 'teamId', 'wins']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'losses',
#        'opponentTeamAbbrev', 'otLosses', 'pointPct', 'points',
#        'shootoutGamesPlayed', 'shootoutGoals', 'shootoutGoalsAgainst',
#        'shootoutLosses', 'shootoutPoints', 'shootoutSavePct', 'shootoutSaves',
#        'shootoutShootingPct', 'shootoutShootingPlusSavePct', 'shootoutShots',
#        'shootoutShotsAgainst', 'shootoutWinPct', 'shootoutWins',
#        'teamFullName', 'teamId', 'wins'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "wins", "losses",
    "otLosses", "points", "pointPct", "shootoutGamesPlayed",
    "shootoutWins", "shootoutLosses", "shootoutPoints",
    "shootoutWinPct", "shootoutGoals", "shootoutShots",
    "shootoutShootingPct", "shootoutShotsAgainst",
    "shootoutGoalsAgainst", "shootoutSaves",
    "shootoutSavePct", "shootoutShootingPlusSavePct"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'wins', 'losses', 'otLosses',
#        'points', 'pointPct', 'shootoutGamesPlayed', 'shootoutWins',
#        'shootoutLosses', 'shootoutPoints', 'shootoutWinPct', 'shootoutGoals',
#        'shootoutShots', 'shootoutShootingPct', 'shootoutShotsAgainst',
#        'shootoutGoalsAgainst', 'shootoutSaves', 'shootoutSavePct',
#        'shootoutShootingPlusSavePct'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Shot Type

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_shottype.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_shottype.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'goalsBackhand', 'goalsDeflected', 'goalsFor', 'goalsSlap', 'goalsSnap', 'goalsTipIn', 'goalsWrapAround', 'goalsWrist', 'homeRoad', 'opponentTeamAbbrev', 'shootingPct', 'shootingPctBackhand', 'shootingPctDeflected', 'shootingPctSlap', 'shootingPctSnap', 'shootingPctTipIn', 'shootingPctWrapAround', 'shootingPctWrist', 'shotsOnNet', 'shotsOnNetBackhand', 'shotsOnNetDeflected', 'shotsOnNetSlap', 'shotsOnNetSnap', 'shotsOnNetTipIn', 'shotsOnNetWrapAround', 'shotsOnNetWrist', 'teamFullName', 'teamId']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'goalsBackhand', 'goalsDeflected',
#        'goalsFor', 'goalsSlap', 'goalsSnap', 'goalsTipIn', 'goalsWrapAround',
#        'goalsWrist', 'homeRoad', 'opponentTeamAbbrev', 'shootingPct',
#        'shootingPctBackhand', 'shootingPctDeflected', 'shootingPctSlap',
#        'shootingPctSnap', 'shootingPctTipIn', 'shootingPctWrapAround',
#        'shootingPctWrist', 'shotsOnNet', 'shotsOnNetBackhand',
#        'shotsOnNetDeflected', 'shotsOnNetSlap', 'shotsOnNetSnap',
#        'shotsOnNetTipIn', 'shotsOnNetWrapAround', 'shotsOnNetWrist',
#        'teamFullName', 'teamId'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "goalsFor",
    "goalsWrist", "goalsSnap", "goalsSlap", "goalsBackhand",
    "goalsTipIn", "goalsDeflected", "goalsWrapAround",
    "shotsOnNet", "shotsOnNetWrist", "shotsOnNetSnap",
    "shotsOnNetSlap", "shotsOnNetBackhand", "shotsOnNetTipIn",
    "shotsOnNetDeflected", "shotsOnNetWrapAround",
    "shootingPct", "shootingPctWrist", "shootingPctSnap",
    "shootingPctSlap", "shootingPctBackhand",
    "shootingPctTipIn", "shootingPctDeflected",
    "shootingPctWrapAround"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'goalsFor', 'goalsWrist',
#        'goalsSnap', 'goalsSlap', 'goalsBackhand', 'goalsTipIn',
#        'goalsDeflected', 'goalsWrapAround', 'shotsOnNet', 'shotsOnNetWrist',
#        'shotsOnNetSnap', 'shotsOnNetSlap', 'shotsOnNetBackhand',
#        'shotsOnNetTipIn', 'shotsOnNetDeflected', 'shotsOnNetWrapAround',
#        'shootingPct', 'shootingPctWrist', 'shootingPctSnap', 'shootingPctSlap',
#        'shootingPctBackhand', 'shootingPctTipIn', 'shootingPctDeflected',
#        'shootingPctWrapAround'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### Team Summary Shooting

# %%
import pandas as pd

path_raw = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\raw\NHL\2025-26\teams\team_summaryshooting.csv"
path_master = r"C:\Users\cadla\Desktop\Documents\2026-top-shelf-analytics\tsa-engine\data\master\NHL\2025-26\teams\team_summaryshooting.csv"

df = pd.read_csv(path_raw)
print(df.columns.tolist())
# Out:
# ['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'opponentTeamAbbrev', 'satAgainst', 'satAhead', 'satBehind', 'satClose', 'satFor', 'satTied', 'satTotal', 'shots5v5', 'teamFullName', 'teamId', 'usatAgainst', 'usatAhead', 'usatBehind', 'usatClose', 'usatFor', 'usatTied', 'usatTotal']

# %%
df.columns
# Out:
# Index(['gameDate', 'gameId', 'gamesPlayed', 'homeRoad', 'opponentTeamAbbrev',
#        'satAgainst', 'satAhead', 'satBehind', 'satClose', 'satFor', 'satTied',
#        'satTotal', 'shots5v5', 'teamFullName', 'teamId', 'usatAgainst',
#        'usatAhead', 'usatBehind', 'usatClose', 'usatFor', 'usatTied',
#        'usatTotal'],
#       dtype='object')

# %%
desired_order = [
    "gameDate", "gameId", "homeRoad", "teamFullName", "teamId",
    "opponentTeamAbbrev", "gamesPlayed", "shots5v5", "satFor",
    "satAgainst", "satTotal", "satTied", "satAhead", 
    "satBehind", "satClose", "usatFor", "usatAgainst",
    "usatTotal", "usatTied", "usatAhead", "usatBehind",
    "usatClose"
]

df = df[desired_order]
df.columns
# Out:
# Index(['gameDate', 'gameId', 'homeRoad', 'teamFullName', 'teamId',
#        'opponentTeamAbbrev', 'gamesPlayed', 'shots5v5', 'satFor', 'satAgainst',
#        'satTotal', 'satTied', 'satAhead', 'satBehind', 'satClose', 'usatFor',
#        'usatAgainst', 'usatTotal', 'usatTied', 'usatAhead', 'usatBehind',
#        'usatClose'],
#       dtype='object')

# %%
# df.to_csv(path, index=False)
df.to_csv(path_master, index=False, encoding="utf-8-sig")

# %% [markdown]
# ### CONVERTING skater_summary.csv to JSON

# %%
import pandas as pd
from pathlib import Path

# === FILE PATHS ===
INPUT_PATH = Path(r"C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.csv")
OUTPUT_PATH = Path(r"C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.json")

# === LOAD CSV ===
df = pd.read_csv(INPUT_PATH)

# === OPTIONAL CLEANING ===

# Convert datetime columns to clean YYYY-MM-DD (adjust column names if needed)
for col in df.columns:
    if "date" in col.lower():
        try:
            df[col] = pd.to_datetime(df[col], errors="coerce").dt.strftime("%Y-%m-%d")
        except Exception:
            pass

# Replace NaN with None (better for JSON)
df = df.where(pd.notnull(df), None)

# === EXPORT JSON ===
df.to_json(
    OUTPUT_PATH,
    orient="records",   # list of row objects (best for frontend)
    indent=2            # pretty format (optional)
)

print(f"✅ JSON file created: {OUTPUT_PATH.resolve()}")
# Out:
# ✅ JSON file created: C:\Users\cadla\Desktop\Documents\2026-TopShelfAnalytics\topshelfanalytics-skater-table\skater_summary.json
